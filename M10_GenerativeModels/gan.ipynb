# %% [markdown]
# # Generative Adversarial Networks (GAN)

# %%
import time
import numpy as np
import torch
import torch.nn.functional as F
from torchvision import datasets
from torchvision import transforms
import torch.nn as nn
from torch.utils.data import DataLoader


if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %%
# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Hyperparameters
random_seed = 123
generator_learning_rate = 0.001
discriminator_learning_rate = 0.001
NUM_EPOCHS = 20
BATCH_SIZE = 128
LATENT_DIM = 75
IMG_SHAPE = (1, 28, 28)
IMG_SIZE = 1
for x in IMG_SHAPE:
    IMG_SIZE *= x



##########################
### MNIST DATASET
##########################

# Note transforms.ToTensor() scales input images
# to 0-1 range
train_dataset = datasets.MNIST(root='data', 
                               train=True, 
                               transform=transforms.ToTensor(),
                               download=True)

test_dataset = datasets.MNIST(root='data', 
                              train=False, 
                              transform=transforms.ToTensor())


train_loader = DataLoader(dataset=train_dataset, 
                          batch_size=BATCH_SIZE, 
                          shuffle=True)

test_loader = DataLoader(dataset=test_dataset, 
                         batch_size=BATCH_SIZE, 
                         shuffle=False)

# Checking the dataset
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    break
# Out:
# Image batch dimensions: torch.Size([128, 1, 28, 28])
# Image label dimensions: torch.Size([128])

# %% [markdown]
# # Model

# %%
class GAN(torch.nn.Module):

    def __init__(self):
        super(GAN, self).__init__()
        
        
        self.generator = nn.Sequential(
            nn.Linear(LATENT_DIM, 128),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(128, IMG_SIZE),
            nn.Tanh()
        )
        
        self.discriminator = nn.Sequential(
            nn.Linear(IMG_SIZE, 128),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )

            
    def generator_forward(self, z):
        img = self.generator(z)
        return img
    
    def discriminator_forward(self, img):
        pred = self.discriminator(img)
        return pred.view(-1)

# %%
torch.manual_seed(random_seed)

model = GAN()
model = model.to(device)

optim_gener = torch.optim.Adam(model.generator.parameters(), lr=generator_learning_rate)
optim_discr = torch.optim.Adam(model.discriminator.parameters(), lr=discriminator_learning_rate)

# %% [markdown]
# # Training

# %%
start_time = time.time()    

discr_costs = []
gener_costs = []
for epoch in range(NUM_EPOCHS):
    model = model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):
        
        features = (features - 0.5)*2.
        features = features.view(-1, IMG_SIZE).to(device) 
        targets = targets.to(device)

        valid = torch.ones(targets.size(0)).float().to(device)
        fake = torch.zeros(targets.size(0)).float().to(device)
        

        ### FORWARD AND BACK PROP
        
        
        # --------------------------
        # Train Generator
        # --------------------------
        
        # Make new images
        z = torch.zeros((targets.size(0), LATENT_DIM)).uniform_(-1.0, 1.0).to(device)
        generated_features = model.generator_forward(z)
        
        # Loss for fooling the discriminator
        discr_pred = model.discriminator_forward(generated_features)
        
        gener_loss = F.binary_cross_entropy(discr_pred, valid)
        
        optim_gener.zero_grad()
        gener_loss.backward()
        optim_gener.step()
        
        # --------------------------
        # Train Discriminator
        # --------------------------        
        
        discr_pred_real = model.discriminator_forward(features.view(-1, IMG_SIZE))
        real_loss = F.binary_cross_entropy(discr_pred_real, valid)
        
        discr_pred_fake = model.discriminator_forward(generated_features.detach())
        fake_loss = F.binary_cross_entropy(discr_pred_fake, fake)
        
        discr_loss = 0.5*(real_loss + fake_loss)

        optim_discr.zero_grad()
        discr_loss.backward()
        optim_discr.step()        
        
        discr_costs.append(discr_loss)
        gener_costs.append(gener_loss)
        
        
        ### LOGGING
        if not batch_idx % 100:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Gen/Dis Loss: %.4f/%.4f' 
                   %(epoch+1, NUM_EPOCHS, batch_idx, 
                     len(train_loader), gener_loss, discr_loss))

    print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))
    
print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
# Out:
# Epoch: 001/020 | Batch 000/469 | Gen/Dis Loss: 0.6562/0.7046
# Epoch: 001/020 | Batch 100/469 | Gen/Dis Loss: 5.6499/0.0315
# Epoch: 001/020 | Batch 200/469 | Gen/Dis Loss: 1.8575/0.0941
# Epoch: 001/020 | Batch 300/469 | Gen/Dis Loss: 1.5732/0.1474
# Epoch: 001/020 | Batch 400/469 | Gen/Dis Loss: 2.3344/0.0776
# Time elapsed: 0.07 min
# Epoch: 002/020 | Batch 000/469 | Gen/Dis Loss: 2.1900/0.1567
# Epoch: 002/020 | Batch 100/469 | Gen/Dis Loss: 2.5784/0.1111
# Epoch: 002/020 | Batch 200/469 | Gen/Dis Loss: 3.2491/0.1714
# Epoch: 002/020 | Batch 300/469 | Gen/Dis Loss: 1.1620/0.4157
# Epoch: 002/020 | Batch 400/469 | Gen/Dis Loss: 0.6749/0.5674
# Time elapsed: 0.14 min
# Epoch: 003/020 | Batch 000/469 | Gen/Dis Loss: 0.7324/0.5159
# Epoch: 003/020 | Batch 100/469 | Gen/Dis Loss: 0.9847/0.3629
# Epoch: 003/020 | Batch 200/469 | Gen/Dis Loss: 1.7628/0.2161
# Epoch: 003/020 | Batch 300/469 | Gen/Dis Loss: 2.2179/0.2258
# Epoch: 003/020 | Batch 400/469 | Gen/Dis Loss: 1.6386/0.3768
# Time elapsed: 0.20 min
# Epoch: 004/020 | Batch 000/469 | Gen/Dis Loss: 1.3339/0.3234
# Epoch: 004/020 | Batch 100/469 | Gen/Dis Loss: 1.3961/0.3950
# Epoch: 004/020 | Batch 200/469 | Gen/Dis Loss: 1.0884/0.3983
# Epoch: 004/020 | Batch 300/469 | Gen/Dis Loss: 1.2673/0.3513
# Epoch: 004/020 | Batch 400/469 | Gen/Dis Loss: 2.4147/0.3353
# Time elapsed: 0.27 min
# Epoch: 005/020 | Batch 000/469 | Gen/Dis Loss: 1.2534/0.3419
# Epoch: 005/020 | Batch 100/469 | Gen/Dis Loss: 0.9496/0.4846
# Epoch: 005/020 | Batch 200/469 | Gen/Dis Loss: 1.1708/0.4975
# Epoch: 005/020 | Batch 300/469 | Gen/Dis Loss: 0.9740/0.4620
# Epoch: 005/020 | Batch 400/469 | Gen/Dis Loss: 1.0530/0.5075
# Time elapsed: 0.34 min
# Epoch: 006/020 | Batch 000/469 | Gen/Dis Loss: 1.0641/0.4443
# Epoch: 006/020 | Batch 100/469 | Gen/Dis Loss: 1.5858/0.4233
# Epoch: 006/020 | Batch 200/469 | Gen/Dis Loss: 0.9983/0.4350
# Epoch: 006/020 | Batch 300/469 | Gen/Dis Loss: 1.1967/0.4663
# Epoch: 006/020 | Batch 400/469 | Gen/Dis Loss: 1.0760/0.5065
# Time elapsed: 0.40 min
# Epoch: 007/020 | Batch 000/469 | Gen/Dis Loss: 2.0082/0.5318
# Epoch: 007/020 | Batch 100/469 | Gen/Dis Loss: 1.1914/0.5486
# Epoch: 007/020 | Batch 200/469 | Gen/Dis Loss: 0.9886/0.5171
# Epoch: 007/020 | Batch 300/469 | Gen/Dis Loss: 1.9211/0.4003
# Epoch: 007/020 | Batch 400/469 | Gen/Dis Loss: 1.2970/0.4582
# Time elapsed: 0.48 min
# Epoch: 008/020 | Batch 000/469 | Gen/Dis Loss: 1.0698/0.4863
# Epoch: 008/020 | Batch 100/469 | Gen/Dis Loss: 1.5931/0.4998
# Epoch: 008/020 | Batch 200/469 | Gen/Dis Loss: 1.1172/0.5384
# Epoch: 008/020 | Batch 300/469 | Gen/Dis Loss: 1.4538/0.4659
# Epoch: 008/020 | Batch 400/469 | Gen/Dis Loss: 1.0496/0.5597
# Time elapsed: 0.55 min
# Epoch: 009/020 | Batch 000/469 | Gen/Dis Loss: 1.0232/0.5051
# Epoch: 009/020 | Batch 100/469 | Gen/Dis Loss: 0.9323/0.5660
# Epoch: 009/020 | Batch 200/469 | Gen/Dis Loss: 1.6477/0.4395
# Epoch: 009/020 | Batch 300/469 | Gen/Dis Loss: 1.0175/0.5401
# Epoch: 009/020 | Batch 400/469 | Gen/Dis Loss: 1.2109/0.4101
# Time elapsed: 0.68 min
# Epoch: 010/020 | Batch 000/469 | Gen/Dis Loss: 0.9087/0.5992
# Epoch: 010/020 | Batch 100/469 | Gen/Dis Loss: 1.1849/0.5123
# Epoch: 010/020 | Batch 200/469 | Gen/Dis Loss: 0.9319/0.5941
# Epoch: 010/020 | Batch 300/469 | Gen/Dis Loss: 0.9718/0.6122
# Epoch: 010/020 | Batch 400/469 | Gen/Dis Loss: 0.9093/0.5142
# Time elapsed: 0.81 min
# Epoch: 011/020 | Batch 000/469 | Gen/Dis Loss: 1.1226/0.5739
# Epoch: 011/020 | Batch 100/469 | Gen/Dis Loss: 0.9788/0.5562
# Epoch: 011/020 | Batch 200/469 | Gen/Dis Loss: 1.1984/0.5257
# Epoch: 011/020 | Batch 300/469 | Gen/Dis Loss: 1.1305/0.5746
# Epoch: 011/020 | Batch 400/469 | Gen/Dis Loss: 1.2264/0.5159
# Time elapsed: 0.94 min
# Epoch: 012/020 | Batch 000/469 | Gen/Dis Loss: 1.0231/0.4563
# Epoch: 012/020 | Batch 100/469 | Gen/Dis Loss: 1.1401/0.5281
# Epoch: 012/020 | Batch 200/469 | Gen/Dis Loss: 1.0727/0.5215
# Epoch: 012/020 | Batch 300/469 | Gen/Dis Loss: 1.0862/0.5314
# Epoch: 012/020 | Batch 400/469 | Gen/Dis Loss: 1.1717/0.5360
# Time elapsed: 1.07 min
# Epoch: 013/020 | Batch 000/469 | Gen/Dis Loss: 1.0285/0.5624
# Epoch: 013/020 | Batch 100/469 | Gen/Dis Loss: 1.0645/0.5726
# Epoch: 013/020 | Batch 200/469 | Gen/Dis Loss: 0.8940/0.6289
# Epoch: 013/020 | Batch 300/469 | Gen/Dis Loss: 1.4585/0.4286
# Epoch: 013/020 | Batch 400/469 | Gen/Dis Loss: 1.8538/0.5456
# Time elapsed: 1.21 min
# Epoch: 014/020 | Batch 000/469 | Gen/Dis Loss: 0.9955/0.5577
# Epoch: 014/020 | Batch 100/469 | Gen/Dis Loss: 0.9244/0.5404
# Epoch: 014/020 | Batch 200/469 | Gen/Dis Loss: 1.1236/0.5304
# Epoch: 014/020 | Batch 300/469 | Gen/Dis Loss: 1.3477/0.4736
# Epoch: 014/020 | Batch 400/469 | Gen/Dis Loss: 1.1996/0.5622
# Time elapsed: 1.34 min
# Epoch: 015/020 | Batch 000/469 | Gen/Dis Loss: 0.9440/0.5576
# Epoch: 015/020 | Batch 100/469 | Gen/Dis Loss: 1.1501/0.5256
# Epoch: 015/020 | Batch 200/469 | Gen/Dis Loss: 1.0905/0.5067
# Epoch: 015/020 | Batch 300/469 | Gen/Dis Loss: 0.9598/0.5675
# Epoch: 015/020 | Batch 400/469 | Gen/Dis Loss: 1.1350/0.6598
# Time elapsed: 1.43 min
# Epoch: 016/020 | Batch 000/469 | Gen/Dis Loss: 1.2004/0.5468
# Epoch: 016/020 | Batch 100/469 | Gen/Dis Loss: 1.1462/0.5251
# Epoch: 016/020 | Batch 200/469 | Gen/Dis Loss: 1.0984/0.5985
# Epoch: 016/020 | Batch 300/469 | Gen/Dis Loss: 1.0541/0.5594
# Epoch: 016/020 | Batch 400/469 | Gen/Dis Loss: 1.0683/0.5800
# Time elapsed: 1.50 min
# Epoch: 017/020 | Batch 000/469 | Gen/Dis Loss: 1.1185/0.5522
# Epoch: 017/020 | Batch 100/469 | Gen/Dis Loss: 1.1512/0.5826
# Epoch: 017/020 | Batch 200/469 | Gen/Dis Loss: 1.6369/0.6265
# Epoch: 017/020 | Batch 300/469 | Gen/Dis Loss: 1.1687/0.5593
# Epoch: 017/020 | Batch 400/469 | Gen/Dis Loss: 1.3984/0.5974
# Time elapsed: 1.57 min
# Epoch: 018/020 | Batch 000/469 | Gen/Dis Loss: 1.2063/0.5194
# Epoch: 018/020 | Batch 100/469 | Gen/Dis Loss: 1.2532/0.5790
# Epoch: 018/020 | Batch 200/469 | Gen/Dis Loss: 1.4918/0.5468
# Epoch: 018/020 | Batch 300/469 | Gen/Dis Loss: 0.9940/0.5677
# Epoch: 018/020 | Batch 400/469 | Gen/Dis Loss: 1.1622/0.5231
# Time elapsed: 1.65 min
# Epoch: 019/020 | Batch 000/469 | Gen/Dis Loss: 1.1197/0.5441
# Epoch: 019/020 | Batch 100/469 | Gen/Dis Loss: 0.9608/0.5332
# Epoch: 019/020 | Batch 200/469 | Gen/Dis Loss: 1.1719/0.5449
# Epoch: 019/020 | Batch 300/469 | Gen/Dis Loss: 1.0803/0.5477
# Epoch: 019/020 | Batch 400/469 | Gen/Dis Loss: 1.2054/0.5478
# Time elapsed: 1.73 min
# Epoch: 020/020 | Batch 000/469 | Gen/Dis Loss: 1.3153/0.5486
# Epoch: 020/020 | Batch 100/469 | Gen/Dis Loss: 1.2452/0.5360
# Epoch: 020/020 | Batch 200/469 | Gen/Dis Loss: 1.0145/0.5432
# Epoch: 020/020 | Batch 300/469 | Gen/Dis Loss: 1.0772/0.5890
# Epoch: 020/020 | Batch 400/469 | Gen/Dis Loss: 1.0762/0.5313
# Time elapsed: 1.80 min
# Total Training Time: 1.80 min

# %% [markdown]
# # Evaluation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
gener_costs[0].item()
# Out:
# 0.6562211513519287

# %%
ax1 = plt.subplot(1, 1, 1)
ax1.plot(range(len(gener_costs)), [gc.item() for gc in gener_costs], label='Generator loss')
ax1.plot(range(len(discr_costs)), [dc.item() for dc in discr_costs], label='Discriminator loss')
ax1.set_xlabel('Iterations')
ax1.set_ylabel('Loss')
ax1.legend()

###################
# Set scond x-axis
ax2 = ax1.twiny()
newlabel = list(range(NUM_EPOCHS+1))
iter_per_epoch = len(train_loader)
newpos = [e*iter_per_epoch for e in newlabel]

ax2.set_xticklabels(newlabel[::10])
ax2.set_xticks(newpos[::10])

ax2.xaxis.set_ticks_position('bottom')
ax2.xaxis.set_label_position('bottom')
ax2.spines['bottom'].set_position(('outward', 45))
ax2.set_xlabel('Epochs')
ax2.set_xlim(ax1.get_xlim())
###################

plt.show()
# Out:
# C:\Users\czhao4\AppData\Local\Temp\ipykernel_11352\3522473664.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(newlabel[::10])

# %% [markdown]
# # Generation

# %%
model.eval()
# Make new images
z = torch.zeros((5, LATENT_DIM)).uniform_(-1.0, 1.0).to(device)
generated_features = model.generator_forward(z)
imgs = generated_features.view(-1, 28, 28)

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(20, 2.5))


for i, ax in enumerate(axes):
    axes[i].imshow(imgs[i].to(torch.device('cpu')).detach(), cmap='binary')
